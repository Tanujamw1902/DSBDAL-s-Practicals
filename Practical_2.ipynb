# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Tanuja/Desktop/Datasets/StudentPerformance.csv")

# %%
df
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0         62.0           76.0           75.0             99.0          2018.0
# 1         79.0           76.0           70.0             96.0          2019.0
# 2         78.0           95.0           69.0             84.0          2018.0
# 3         69.0           92.0           71.0             81.0          2020.0
# 4         76.0           95.0           61.0             88.0          2018.0
# 5          NaN           85.0           77.0             78.0          2021.0
# 6         71.0           82.0           62.0              NaN          2019.0
# 7         77.0           87.0            NaN             97.0          2021.0
# 8         77.0           93.0           67.0             87.0          2018.0
# 9         62.0           90.0           64.0             89.0             NaN
# 10        75.0           91.0           79.0             86.0          2021.0
# ...

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  placement score  club join year  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5         True          False          False            False           False
# 6        False          False          False             True           False
# 7        False          False           True            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False            True
# 10       False          False          False            False           False
# ...

# %%
df.isnull().sum().sum()
# Out:
# 12

# %%
df.columns
# Out:
# Index(['math score', 'reading score', 'writing score', 'placement score',
#        'club join year', 'placement offer count'],
#       dtype='object')

# %%
col=['math score', 'reading score', 'writing score', 'placement score']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(df.loc[df['reading score']<69])
# Out:
# Empty DataFrame
# Columns: [math score, reading score, writing score, placement score, club join year, placement offer count]
# Index: []

# %%
print(np.where(df['reading score']<60))
# Out:
# (array([], dtype=int64),)

# %%
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['placement score'], df['placement offer count'])
plt.show()

# %%
print(np.where((df['placement score']<50) & (df['placement offer count']>1))) #relating to each other
# Out:
# (array([], dtype=int64),)

# %%
import numpy as np
from scipy import stats

# %%
z = np.abs(stats.zscore(df['math score'])) #z score for math_column

# %%
df['math score'].isnull()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# Name: math score, dtype: bool

# %%
print(z)
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# Name: math score, dtype: float64

# %%
threshold=0.18

# %%
sample_outliers = np.where(z <threshold)
sample_outliers
# Out:
# (array([], dtype=int64),)

# %%
sorted_rscore=sorted(df['reading score'])
sorted_rscore  #sorting reading score
# Out:
# [76.0,
#  76.0,
#  76.0,
#  78.0,
#  79.0,
#  80.0,
#  80.0,
#  80.0,
#  82.0,
#  82.0,
#  85.0,
#  85.0,
#  86.0,
#  87.0,
#  88.0,
#  88.0,
#  89.0,
#  90.0,
#  91.0,
#  91.0,
#  92.0,
#  92.0,
#  92.0,
#  93.0,
#  93.0,
#  93.0,
#  95.0,
#  95.0,
#  nan,
#  nan]

# %%
q1=np.percentile(sorted_rscore,25)
q3=np.percentile(sorted_rscore,75)
print(q1,q3)
# Out:
# nan nan

# %%
IQR=q3-q1

# %%
IQR
# Out:
# nan

# %%
lwr_bound=q1-(1.5*IQR)
upr_bound=q3+(1.5*IQR)
print(lwr_bound,upr_bound)
# Out:
# nan nan

# %%
r_outliers=[]
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
        print(r_outliers)

# %%
r_outliers
# Out:
# []
